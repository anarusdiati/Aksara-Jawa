# %% [markdown]
# <a href="https://colab.research.google.com/github/anarusdiati/Aksara-Jawa/blob/main/aksara_jawa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline
import time

# %%
dataset = pd.read_excel('dataset.xlsx')
dataset
# Out:
#                           data               aksara_dasar
# 0                           ha                         ha
# 1                           na                         na
# 2                           ca                         ca
# 3                           ra                         ra
# 4                           ka                         ka
# 5                           da                         da
# 6                           ta                         ta
# 7                           sa                         sa
# 8                           wa                         wa
# 9                           la                         la
# 10                          pa                         pa
# 11                         dha                        dha
# 12                          ja                         ja
# 13                          ya                         ya
# 14                         nya                        nya
# ...

# %%
def check(query):
    for i in range(len(dataset)):
        penyusun_aksara = dataset['aksara_dasar'][i].split(",")
        if query in penyusun_aksara: 
            aksara = dataset['data'][i]
            #output(aksara)
            print(aksara)

# %%
def output(aksara):
    path = "C:/Users/ASUS/Documents/Tugas STBI/dataset/"+aksara+".jpg"
    img = cv2.imread(path)
    plt.imshow(img)
    plt.axis('off')
    plt.show()
    print("Aksara di atas dibaca: ", aksara)
    print("_________________________________________________________")

# %%
def run():
    masukkan = input ("Masukkan satu huruf aksara Jawa: ")
    masuk = masukkan.lower()
    start_time = time.time()
    check(masuk)
    return ("Waktu pencarian: %s detik" % (time.time()-start_time))

# %%
run()
# Out:
# Masukkan satu huruf aksara Jawa: nga
# nga
# mangan
# aku mangan tahu
# jare lungo mung sedela
# kula nyuwun pangapunten
# adikku mangan sega
# matur nuwun sanget
# 'Waktu pencarian: 0.000982522964477539 detik'

# %%
aks = ['ha','na','ca','ra','ka',
       'da','ta','sa','wa','la',
       'pa','dha','ja','ya','nya',
       'ma','ga','ba','tha','nga']

for i in range(len(dataset)):
    run(aks[i])
# Out:
# 51
